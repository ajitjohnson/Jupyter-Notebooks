# %% [markdown]
# 12/14/18
# Data generated by Wenchao

# %% [markdown]
# ## Import Library

# %%
library(limma)
library(edgeR)

# %% [markdown]
# #### Working directory

# %%
# DFCI
setwd ("Z:/Ajit/wenchao data")

# %% [markdown]
# ## Import data

# %%
data <- read.table("RawData.txt", header=T, sep="\t")
pdata <- read.table("pdata.txt", header=T, sep="\t")

# %% [markdown]
# ### Pre-processing

# %%
# Remove transcripts that are not expressed
data <- data[rowSums(data[2:ncol(data)])!=0, ]
dim (data)
# Out:
# [1] 20654    19

# %%
# Normalise data using limma-voom
# Create design matrix
design <- model.matrix(~ pdata$Resistance)
# Apply voom transformation
nf <- calcNormFactors(data[2:ncol(data)])
v <- voom(data[2:ncol(data)], design, lib.size=colSums(data[2:ncol(data)])*nf, normalize.method="quantile", plot=TRUE)
# Out:
# Plot with title "voom: Mean-variance trend"

# %%
# Extract normalised data
n_data <- data.frame(v$E)
n_data$gene <- data$Gene_ID

# %%
dim(n_data)
# Out:
# [1] 20654    19

# %%
head(n_data)
# Out:
#    P1_DMSO   P2_DMSO   P3_DMSO   P1_Len    P2_Len    P3_Len    P1_Pom
# 20 0.9745245 0.9745245 0.9745245 0.9745245 0.9745245 0.9745245 0.9745245
# 29 0.9745245 0.9745245 0.9745245 2.2072732 0.9745245 0.9745245 2.1192197
# 31 2.2072732 2.2072732 0.9745245 0.9745245 0.9745245 0.9745245 0.9745245
# 38 2.8275796 2.8275796 2.2072732 0.9745245 0.9745245 0.9745245 2.1192197
# 40 6.1033910 5.4685295 4.7350112 4.8357364 4.5060692 0.9745245 5.0382928
# 41 5.1401579 5.1339895 5.1131164 4.2197089 4.0888807 0.9745245 4.8908690
#    P2_Pom    P3_Pom    R1_DMSO   R2_DMSO   R3_DMSO   R1_Len    R2_Len
# 20 0.9745245 0.9745245 2.2072732 0.9745245 0.9745245 0.9745245 0.9745245
# 29 0.9745245 0.9745245 0.9745245 0.9745245 0.9745245 0.9745245 0.9745245
# 31 0.9745245 0.9745245 0.9745245 0.9745245 0.9745245 0.9745245 0.9745245
# 38 3.1992890 0.9745245 0.9745245 0.9745245 0.9745245 0.9745245 0.9745245
# 40 5.0935819 5.0087207 5.1131164 5.2600268 5.9381514 6.0685052 4.1719111
# 41 5.8859599 5.8681887 3.6840394 3.8898780 3.6638966 4.7528407 3.3474472
#    R3_Len    R1_Pom    R2_Pom    R3_Pom    gene
# 20 0.9745245 0.9745245 0.9745245 2.2072732 7SK
# 29 0.9745245 0.9745245 0.9745245 0.9745245 A1BG-AS1
# 31 0.9745245 0.9745245 0.9745245 0.9745245 A2M
# 38 0.9745245 0.9745245 0.9745245 0.9745245 A4GALT
# 40 4.8036498 5.2247559 5.5076424 6.1169432 AAAS
# 41 5.5673668 4.7528407 2.2072732 4.2197089 AACS
